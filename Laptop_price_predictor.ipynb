# %% [markdown]
# #1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #2. Importing Dataset

# %%
df=pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %% [markdown]
# #3. Deleting the column ('Unnamed') present in the given dataset

# %%
df.drop(columns=['Unnamed: 0',],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %% [markdown]
# #4. Replacing the word 'GB' and 'kg' present in the column 'Ram' and 'Weight' present in the given dataset

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head()
## Still the Ram and Weight column will be in object datatype
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %% [markdown]
# #5. Coverting the datatype of the column 'Ram' and 'Weight' from object to int32 and float32 respectively

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # Performing EDA Analysis.......

# %%
sns.distplot(df['Price'],hist=False)
# Out:
# <ipython-input-10-ed94b44bd51a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],hist=False)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
sns.barplot(x='Company',y='Price',data=df)
plt.xticks(rotation='vertical') ## This syntax is used to adjust the x-label vertically in the graph
plt.show()

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
sns.barplot(x='TypeName',y='Price',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'],hist=False)
# Out:
# <ipython-input-15-b9833431df4c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'],hist=False)
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x='Inches',y='Price',data=df)
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if('Touchscreen') in x else 0)

# %%
df.tail()
# Out:
#      Company            TypeName  Inches  \
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz    4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
#
# ...

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
sns.barplot(x='Touchscreen',y='Price',data=df)
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if('IPS') in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x='IPS',y='Price',data=df)
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new=df['ScreenResolution'].str.split('x',expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
## This line of code I need to understand later

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res']=df['X_res'].astype('int32')
df['Y_res']=df['Y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df['ppi']=((df['X_res'])**2+(df['Y_res'])**2)**0.5/df['Inches'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983001
# 1  127.677938
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# ...

# %%
def fetch_processor(text):
  if(text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3'):
    return text
  else:
    if(text.split()[0]=='Intel'):
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu brand']=df['Cpu Name'].apply(fetch_processor)

# %%
df.head(10)
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
# 5    Acer   Notebook     AMD A9-Series 9420 3GHz    4            500GB HDD
# 6   Apple  Ultrabook        Intel Core i7 2.2GHz   16  256GB Flash Storage
# 7   Apple  Ultrabook        Intel Core i5 1.8GHz    8  256GB Flash Storage
# 8    Asus  Ultrabook  Intel Core i7 8550U 1.8GHz   16            512GB SSD
# 9    Acer  Ultrabook  Intel Core i5 8250U 1.6GHz    8            256GB SSD
#
#                             Gpu       OpSys  Weight        Price  Touchscreen  \
# ...

# %%
sns.barplot(x='Cpu brand',y='Price',data=df)
# Out:
# <Axes: xlabel='Cpu brand', ylabel='Price'>

# %%
df.drop(columns=['Cpu'],inplace=True)

# %%
df.drop(columns=['Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983001  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677938  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211995  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534629  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983001  Intel Core i5

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(x='Ram',y='Price',data=df)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
#df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
new=df['Memory'].str.split('+',n=1,expand=True)
df["first"]= new[0]
df['first']=df['first'].str.strip()
df["second"]= new[1]
df["second"]=df["second"].str.strip()
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['first']=df['first'].apply(lambda x:x.split(" ")[0])
df["second"].fillna("0", inplace = True)
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
df['first']=df['first'].astype(float)
df["second"]=df["second"].apply(lambda x:x.split(" ")[0])
df["second"]=df["second"].astype(float)
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
df.sample(5)
# Out:
#     Company  TypeName  Ram               Memory                      Gpu  \
# 687    Dell  Notebook    4             1000 HDD       AMD Radeon R5 M430
# 625  Lenovo  Notebook    8             1000 HDD     Nvidia GeForce 920MX
# 454    Dell  Notebook    8  128 SSD +  1000 HDD           AMD Radeon 530
# 465    Asus  Notebook    4              500 HDD    Intel HD Graphics 500
# 738     MSI    Gaming   16  256 SSD +  1000 HDD  Nvidia GeForce GTX 1060
#
#           OpSys  Weight        Price  Touchscreen  IPS         ppi  \
# 687  Windows 10    2.20   29073.2976            0    0  100.454667
# 625  Windows 10    2.20   47898.7200            0    0  141.211995
# 454  Windows 10    2.36   52161.1200            0    0  141.211995
# 465  Windows 10    2.00   16197.1200            0    0  100.454667
# 738  Windows 10    1.80  111593.8944            0    0  141.211995
#
#                  Cpu brand     HDD    SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample(5)
# Out:
#       Company            TypeName  Ram                      Gpu       OpSys  \
# 1073       HP            Notebook    8    Intel HD Graphics 620  Windows 10
# 80       Dell           Ultrabook    8   Intel UHD Graphics 620  Windows 10
# 380        HP              Gaming    8  Nvidia GeForce GTX 1050  Windows 10
# 253    Lenovo  2 in 1 Convertible    8   Intel UHD Graphics 620  Windows 10
# 825   Toshiba            Notebook    4    Intel HD Graphics 510  Windows 10
#
#       Weight       Price  Touchscreen  IPS         ppi              Cpu brand  \
# 1073    1.49  58075.2000            0    0  165.632116          Intel Core i7
# 80      1.88  58403.4048            0    1  141.211995          Intel Core i5
# 380     3.35  63456.4800            0    1  127.335680          Intel Core i7
# 253     1.37  98514.7200            1    1  158.482535          Intel Core i7
# 825     1.75  26586.7200            0    0  111.935204  Other Intel Processor
#
# ...

# %%
df['HDD'].value_counts()
# Out:
# HDD
# 0.0       727
# 1000.0    407
# 500.0     134
# 2000.0     32
# 32.0        1
# 128.0       1
# 1.0         1
# Name: count, dtype: int64

# %%
df['SSD'].value_counts()
# Out:
# SSD
# 256.0     498
# 0.0       460
# 128.0     172
# 512.0     138
# 1000.0     16
# 32.0        6
# 180.0       5
# 16.0        3
# 64.0        1
# 1024.0      1
# 768.0       1
# 240.0       1
# 8.0         1
# Name: count, dtype: int64

# %%
df['Hybrid'].value_counts()
# Out:
# Hybrid
# 0.0      1291
# 1.0        11
# 508.0       1
# Name: count, dtype: int64

# %%
df['Flash_Storage'].value_counts()
# Out:
# Flash_Storage
# 0.0      1228
# 32.0       38
# 64.0       16
# 256.0       8
# 16.0        7
# 128.0       4
# 512.0       2
# Name: count, dtype: int64

# %%
sns.barplot(x='Hybrid',y='Price',data=df)
# Out:
# <Axes: xlabel='Hybrid', ylabel='Price'>

# %%
sns.barplot(x='HDD',y='Price',data=df)
# Out:
# <Axes: xlabel='HDD', ylabel='Price'>

# %%
sns.barplot(x='SSD',y='Price',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x='Flash_Storage',y='Price',data=df)
# Out:
# <Axes: xlabel='Flash_Storage', ylabel='Price'>

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram                    Gpu       OpSys  Weight  \
# 399   Lenovo  Ultrabook   16  Intel HD Graphics 620  Windows 10    1.13
# 1242    Acer   Notebook    4  Intel HD Graphics 520       Linux    2.40
# 731     Dell   Notebook   12  Intel HD Graphics 620  Windows 10    2.25
# 946     Dell  Ultrabook    8      Intel HD Graphics  Windows 10    1.36
# 202     Acer   Notebook    8   Nvidia GeForce 940MX  Windows 10    2.23
#
#            Price  Touchscreen  IPS         ppi      Cpu brand     HDD     SSD
# 399   139860.000            0    1  209.800683  Intel Core i7     0.0  1000.0
# 1242   19276.704            0    0  100.454667  Intel Core i3   500.0     0.0
# 731    34578.720            0    0  100.454667  Intel Core i5  1000.0     0.0
# 946    78438.816            1    0  176.232574  Intel Core i5     0.0   256.0
# 202    39533.760            0    0  141.211995  Intel Core i7  1000.0     0.0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].str.split(" ",n=1).str[0]

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  Touchscreen  IPS         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983001
# ...

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df[df['Gpu_brand']=='ARM']
# In this way we can access a particular row in which the value 'ARM' is present in the column "Gpu_brand" of the dataframe df
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#          Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD  \
# 1191  35111.52            1    1  234.507396  AMD Processor  0.0  0.0
#
#      Gpu_brand
# 1191       ARM

# %%
df.drop(1191,axis=0,inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  Touchscreen  IPS         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983001
# ...

# %%
df['Gpu_brand'].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x='Gpu_brand',y='Price',data=df)
# Out:
# <Axes: xlabel='Gpu_brand', ylabel='Price'>

# %%
df['HDD']=df['HDD'].astype('int32')

# %%
df['HDD'].value_counts()
# Out:
# HDD
# 0       726
# 1000    407
# 500     134
# 2000     32
# 32        1
# 128       1
# 1         1
# Name: count, dtype: int64

# %%
df['SSD']=df['SSD'].astype('int32')
df.sample(6)
# Out:
#      Company            TypeName  Ram                     Gpu       OpSys  \
# 1271  Lenovo  2 in 1 Convertible   16   Intel HD Graphics 520  Windows 10
# 1253  Lenovo            Notebook    8   Intel HD Graphics 520  Windows 10
# 1155      HP            Notebook    4          AMD Radeon 520  Windows 10
# 92        HP            Notebook   16  Intel UHD Graphics 620  Windows 10
# 118     Asus            Notebook    4    Nvidia GeForce 920MX  Windows 10
# 537       HP            Notebook    4   Intel HD Graphics 405  Windows 10
#
#       Weight       Price  Touchscreen  IPS         ppi              Cpu brand  \
# 1271    1.30  79866.7200            1    1  276.053526          Intel Core i7
# 1253    1.90  57116.1600            0    1  157.350512          Intel Core i5
# 1155    1.91  25515.2592            0    0  141.211995          AMD Processor
# 92      1.49  63776.1600            0    0  165.632116          Intel Core i7
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x='OpSys',y='Price',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
def cnage_os(text):
   if(text=='Windows 10' or text=='Windows 7' or text=='Windows 10 S'):
     return('Windows')
   elif(text=='macOS' or text=='Mac OS X'):
     return('Mac')
   else:
     return('Other OS')

# %%
df['os']=df['OpSys'].apply(cnage_os)
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  Touchscreen  IPS         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983001
# ...

# %%
df.drop(columns=['OpSys','Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983001
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677938
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211995
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534629
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983001
#
#        Cpu brand  HDD  SSD Gpu_brand        os
# 0  Intel Core i5    0  128     Intel       Mac
# 1  Intel Core i5    0    0     Intel       Mac
# 2  Intel Core i5    0  256     Intel  Other OS
# 3  Intel Core i7    0  512       AMD       Mac
# 4  Intel Core i5    0  256     Intel       Mac

# %%
df['os'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='os'>

# %%
sns.barplot(x='os',y='Price',data=df)
# Out:
# <Axes: xlabel='os', ylabel='Price'>

# %%
sns.distplot(df['Weight'],hist=False)
# Out:
# <ipython-input-85-19f4fe2b88df>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'],hist=False)
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x='Weight',y='Price',data=df)
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.distplot(df['Price'],hist=False)
# from the plot of price we can clearly see that our price column is skewed slightly....
# In order to solve this problem we are going to take log of it
# Out:
# <ipython-input-87-ded0addf384f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],hist=False)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']),hist=False)
# Out:
# <ipython-input-88-d742759b885a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']),hist=False)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
x=df.drop(columns='Price')
y=np.log(df["Price"])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983001
# 1      Apple           Ultrabook    8    1.34            0    0  127.677938
# 2         HP            Notebook    8    1.86            0    0  141.211995
# 3      Apple           Ultrabook   16    1.83            0    1  220.534629
# 4      Apple           Ultrabook    8    1.37            0    1  226.983001
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053526
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454667
# 1302    Asus            Notebook    4    2.20            0    0  100.454667
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454667
# 1141      MSI              Gaming    8    2.40            0    0  141.211995
# 1049     Asus             Netbook    4    1.20            0    0  135.094207
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211995
# 878      Dell            Notebook    4    2.18            0    0  141.211995
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454667
# 299      Asus           Ultrabook   16    1.63            0    0  141.211995
# 493      Acer            Notebook    8    2.20            0    0  100.454667
# 527    Lenovo            Notebook    8    2.20            0    0  100.454667
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
x_test
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632116
# 555     Asus            Notebook    4    2.00            0    0  100.454667
# 1251      HP            Notebook    4    1.86            0    0  100.454667
# 547   Lenovo            Notebook    4    2.15            0    0  141.211995
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632116
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335680
# 172   Lenovo            Notebook    4    2.20            0    0  100.454667
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632116
# 470       HP  2 in 1 Convertible    8    1.29            1    1  331.264231
#
# ...

# %%
y_train
# Out:
# 183     10.651384
# 1141    11.016798
# 1049     9.638174
# 1020    10.655148
# 878     10.791749
#           ...
# 466     10.126164
# 299     11.267217
# 493     10.336864
# 527     10.104611
# 1193    11.034319
# Name: Price, Length: 1106, dtype: float64

# %%
y_test
# Out:
# 248     10.490274
# 555      9.387207
# 1251     9.964522
# 547     10.111883
# 885     11.470547
#           ...
# 1129    11.004649
# 172      9.708902
# 322     10.973157
# 996     11.182680
# 470     11.575963
# Name: Price, Length: 196, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score

# %%
df['os'].isnull().sum()
# Out:
# 0

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983001
#
#        Cpu brand  HDD  SSD Gpu_brand   os
# 0  Intel Core i5    0  128     Intel  Mac

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %% [markdown]
# ## Linear Regression

# %%
step1=ColumnTransformer(transformers=[
    ('OHE',OneHotEncoder(drop='first',sparse=False),[0,1,7,10,11])
],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# r2_score:  0.8072993973173674
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Ridge Regression

# %%
step1=ColumnTransformer(transformers=[
    ('OHE',OneHotEncoder(drop='first',sparse=False),[0,1,7,10,11])
],remainder='passthrough')
step2=Ridge(alpha=10)
pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# r2_score:  0.8127220647174144
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Lasso Regression

# %%
step1=ColumnTransformer(transformers=[
    ('OHE',OneHotEncoder(drop='first',sparse=False),[0,1,7,10,11])
],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)

])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# r2_score:  0.8071645336322267
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## KNN Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print('R2 score',r2_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7986468149920843

# %% [markdown]
# ## Decision Tree Regression

# %%
step1=ColumnTransformer(transformers=[
    ('OHE',OneHotEncoder(drop='first',sparse=False),[0,1,7,10,11])
],remainder='passthrough')
step2=DecisionTreeRegressor(random_state=0,max_depth=8)
pipe=Pipeline(
    [
        ('step1',step1),
        ('step2',step2)
    ]
)
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# r2_score:  0.8434091032939807
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Support Vector Regression

# %%
step1=ColumnTransformer(transformers=[
    ('OHE',OneHotEncoder(drop='first',sparse=False),[0,1,7,10,11])
],remainder='passthrough')
step2=SVR(kernel='rbf')
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train,y_train)
y_predd=pipe.predict(x_test)
print('r2_score: ',r2_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2_score:  0.8434091032939807

# %% [markdown]
# ## Random Forest Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
#print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8872322449396131

# %% [markdown]
# ## Exporting the Model

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...
